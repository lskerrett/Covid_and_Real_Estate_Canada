# %%
import pandas as pd
import datetime as dt

# %%
price_index=pd.read_csv("./Resources/New_housing_index_price.csv")
price_index.head()
# Out:
#      REF_DATE              GEO           DGUID New housing price indexes  \
# 0  1981-01-01           Canada  2016A000011124    Total (house and land)
# 1  1981-01-01           Canada  2016A000011124                House only
# 2  1981-01-01           Canada  2016A000011124                 Land only
# 3  1981-01-01  Atlantic Region      2016A00011    Total (house and land)
# 4  1981-01-01  Atlantic Region      2016A00011                House only
#
#                  UOM  UOM_ID SCALAR_FACTOR  SCALAR_ID      VECTOR  COORDINATE  \
# 0  Index, 201612=100     347        units           0  v111955442         1.1
# 1  Index, 201612=100     347        units           0  v111955443         1.2
# 2  Index, 201612=100     347        units           0  v111955444         1.3
# 3  Index, 201612=100     347        units           0  v111955445         2.1
# 4  Index, 201612=100     347        units           0  v111955446         2.2
#
#    VALUE STATUS  SYMBOL  TERMINATED  DECIMALS
# ...

# %%
price_index.columns.tolist()
# Out:
# ['REF_DATE',
#  'GEO',
#  'DGUID',
#  'New housing price indexes',
#  'UOM',
#  'UOM_ID',
#  'SCALAR_FACTOR',
#  'SCALAR_ID',
#  'VECTOR',
#  'COORDINATE',
#  'VALUE',
#  'STATUS',
#  'SYMBOL',
#  'TERMINATED',
#  'DECIMALS']

# %%
price_index.dtypes
# Out:
# REF_DATE                      object
# GEO                           object
# DGUID                         object
# New housing price indexes     object
# UOM                           object
# UOM_ID                         int64
# SCALAR_FACTOR                 object
# SCALAR_ID                      int64
# VECTOR                        object
# COORDINATE                   float64
# VALUE                        float64
# STATUS                        object
# SYMBOL                       float64
# TERMINATED                   float64
# DECIMALS                       int64
# dtype: object

# %%
price_index = price_index.drop(["TERMINATED", "SYMBOL","DECIMALS", "DGUID","STATUS","UOM","UOM_ID","SCALAR_FACTOR","SCALAR_ID","VECTOR","COORDINATE"], axis=1)

# %%
price_index.head()
# Out:
#      REF_DATE              GEO New housing price indexes  VALUE
# 0  1981-01-01           Canada    Total (house and land)   38.2
# 1  1981-01-01           Canada                House only   36.1
# 2  1981-01-01           Canada                 Land only   40.6
# 3  1981-01-01  Atlantic Region    Total (house and land)    NaN
# 4  1981-01-01  Atlantic Region                House only    NaN

# %%
pd.to_datetime(price_index["REF_DATE"])
# Out:
# 0       1981-01-01
# 1       1981-01-01
# 2       1981-01-01
# 3       1981-01-01
# 4       1981-01-01
#            ...
# 56995   2020-07-20
# 56996   2020-07-20
# 56997   2020-07-20
# 56998   2020-07-20
# 56999   2020-07-20
# Name: REF_DATE, Length: 57000, dtype: datetime64[ns]

# %%
price_index = price_index.rename(columns = {"VALUE":"UNIT_VALUE","New housing price indexes":"Price_Indexes"})

# %%
price_index.head()
# Out:
#      REF_DATE              GEO           Price_Indexes  UNIT_VALUE
# 0  1981-01-01           Canada  Total (house and land)        38.2
# 1  1981-01-01           Canada              House only        36.1
# 2  1981-01-01           Canada               Land only        40.6
# 3  1981-01-01  Atlantic Region  Total (house and land)         NaN
# 4  1981-01-01  Atlantic Region              House only         NaN

# %%
price_index=price_index.dropna()

# %%
price_index=price_index[price_index.Price_Indexes != "Total (house and land)"]
price_index.head()
# Out:
#       REF_DATE                                                GEO  \
# 1   1981-01-01                                             Canada
# 2   1981-01-01                                             Canada
# 10  1981-01-01              St. John's, Newfoundland and Labrador
# 11  1981-01-01              St. John's, Newfoundland and Labrador
# 28  1981-01-01  Saint John, Fredericton, and Moncton, New Brun...
#
#    Price_Indexes  UNIT_VALUE
# 1     House only        36.1
# 2      Land only        40.6
# 10    House only        37.5
# 11     Land only        31.4
# 28    House only        61.4

# %%
price_index["GEO"].nunique()
# Out:
# 40

# %%
price_index=price_index[(price_index.GEO!="Canada") & (price_index.GEO!="Atlantic Region") & (price_index.GEO!="Prairie Region")]
price_index.head()
# Out:
#       REF_DATE                                                GEO  \
# 10  1981-01-01              St. John's, Newfoundland and Labrador
# 11  1981-01-01              St. John's, Newfoundland and Labrador
# 28  1981-01-01  Saint John, Fredericton, and Moncton, New Brun...
# 29  1981-01-01  Saint John, Fredericton, and Moncton, New Brun...
# 34  1981-01-01                                     Québec, Quebec
#
#    Price_Indexes  UNIT_VALUE
# 10    House only        37.5
# 11     Land only        31.4
# 28    House only        61.4
# 29     Land only        38.0
# 34    House only        34.9

# %%
price_index.reset_index(drop=True)
# Out:
#          REF_DATE                                                GEO  \
# 0      1981-01-01              St. John's, Newfoundland and Labrador
# 1      1981-01-01              St. John's, Newfoundland and Labrador
# 2      1981-01-01  Saint John, Fredericton, and Moncton, New Brun...
# 3      1981-01-01  Saint John, Fredericton, and Moncton, New Brun...
# 4      1981-01-01                                     Québec, Quebec
# ...           ...                                                ...
# 28141  2020-07-20                          Kelowna, British Columbia
# 28142  2020-07-20                        Vancouver, British Columbia
# 28143  2020-07-20                        Vancouver, British Columbia
# 28144  2020-07-20                         Victoria, British Columbia
# 28145  2020-07-20                         Victoria, British Columbia
#
#       Price_Indexes  UNIT_VALUE
# 0        House only        37.5
# 1         Land only        31.4
# 2        House only        61.4
# ...

# %%
price_index.to_csv('price_index_clean.csv',index=False)
