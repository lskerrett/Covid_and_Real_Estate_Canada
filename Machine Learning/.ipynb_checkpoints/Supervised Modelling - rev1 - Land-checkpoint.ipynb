# %%
# Import Dependicies
import pandas as pd
from sklearn import linear_model
import statsmodels.api as sm
from datetime import datetime

# %%
city_df = pd.read_csv("../Resources/cleaned_canada_pop_2011_2016.csv")
city_df.head()
# Out:
#     city_name                               city_size_type  \
# 0       Acton    Small population centre (1,000 to 29,999)
# 1  Acton Vale    Small population centre (1,000 to 29,999)
# 2     Airdrie  Medium population centre (30,000 to 99,999)
# 3     Alençon    Small population centre (1,000 to 29,999)
# 4  Alexandria    Small population centre (1,000 to 29,999)
#
#                                            city_type province  pop_2016  \
# 0                                             Fringe  Ontario    9462.0
# 1  Population centre outside metropolitan area / ...   Quebec    5399.0
# 2                                     Secondary core  Alberta   61082.0
# 3  Population centre outside metropolitan area / ...   Quebec    1562.0
# 4  Population centre outside metropolitan area / ...  Ontario    2845.0
#
#    city_size  pop_density
# 0       7.80       1213.2
# 1       4.30       1254.2
# 2      32.78       1863.2
# 3       2.94        530.4
# 4       2.07       1375.1

# %%
housing_price_df = pd.read_csv("../Resources/price_index_clean.csv")
housing_price_df.head()
# Out:
#    housingprice_index    REF_DATE        City                   Province  \
# 0                   0  1981-01-01  St. John's  Newfoundland and Labrador
# 1                   1  1981-01-01  St. John's  Newfoundland and Labrador
# 2                   2  1981-01-01  Saint John                Fredericton
# 3                   3  1981-01-01  Saint John                Fredericton
# 4                   4  1981-01-01      Québec                     Quebec
#
#   Housing_Type  PRICE_INDEX
# 0   House only           37
# 1    Land only           31
# 2   House only           61
# 3    Land only           38
# 4   House only           34

# %%
city_df.head()
# Out:
#     city_name                               city_size_type  \
# 0       Acton    Small population centre (1,000 to 29,999)
# 1  Acton Vale    Small population centre (1,000 to 29,999)
# 2     Airdrie  Medium population centre (30,000 to 99,999)
# 3     Alençon    Small population centre (1,000 to 29,999)
# 4  Alexandria    Small population centre (1,000 to 29,999)
#
#                                            city_type province  pop_2016  \
# 0                                             Fringe  Ontario    9462.0
# 1  Population centre outside metropolitan area / ...   Quebec    5399.0
# 2                                     Secondary core  Alberta   61082.0
# 3  Population centre outside metropolitan area / ...   Quebec    1562.0
# 4  Population centre outside metropolitan area / ...  Ontario    2845.0
#
#    city_size  pop_density
# 0       7.80       1213.2
# 1       4.30       1254.2
# 2      32.78       1863.2
# 3       2.94        530.4
# 4       2.07       1375.1

# %%
housing_price_df = housing_price_df.drop(columns = ["housingprice_index"])
housing_price_df.head()
# Out:
#      REF_DATE        City                   Province Housing_Type  PRICE_INDEX
# 0  1981-01-01  St. John's  Newfoundland and Labrador   House only           37
# 1  1981-01-01  St. John's  Newfoundland and Labrador    Land only           31
# 2  1981-01-01  Saint John                Fredericton   House only           61
# 3  1981-01-01  Saint John                Fredericton    Land only           38
# 4  1981-01-01      Québec                     Quebec   House only           34

# %%
# Merging the Various databases 
combined_df_1 = pd.merge(housing_price_df, city_df,  how='inner', left_on=['City','Province'], right_on = ['city_name','province'])
combined_df_1.head()
# Out:
#      REF_DATE        City                   Province Housing_Type  \
# 0  1981-01-01  St. John's  Newfoundland and Labrador   House only
# 1  1981-01-01  St. John's  Newfoundland and Labrador    Land only
# 2  1981-02-01  St. John's  Newfoundland and Labrador   House only
# 3  1981-02-01  St. John's  Newfoundland and Labrador    Land only
# 4  1981-03-01  St. John's  Newfoundland and Labrador   House only
#
#    PRICE_INDEX   city_name                                   city_size_type  \
# 0           37  St. John's  Large urban population centre (100,000 or more)
# 1           31  St. John's  Large urban population centre (100,000 or more)
# 2           37  St. John's  Large urban population centre (100,000 or more)
# 3           31  St. John's  Large urban population centre (100,000 or more)
# 4           37  St. John's  Large urban population centre (100,000 or more)
#
#   city_type                   province  pop_2016  city_size  pop_density
# 0      Core  Newfoundland and Labrador  178427.0      166.0       1074.9
# 1      Core  Newfoundland and Labrador  178427.0      166.0       1074.9
# 2      Core  Newfoundland and Labrador  178427.0      166.0       1074.9
# 3      Core  Newfoundland and Labrador  178427.0      166.0       1074.9
# 4      Core  Newfoundland and Labrador  178427.0      166.0       1074.9

# %%
combined_df_1 = combined_df_1.drop(columns = ["city_name" , "province"])
combined_df_1
# Out:
#          REF_DATE        City                   Province Housing_Type  \
# 0      1981-01-01  St. John's  Newfoundland and Labrador   House only
# 1      1981-01-01  St. John's  Newfoundland and Labrador    Land only
# 2      1981-02-01  St. John's  Newfoundland and Labrador   House only
# 3      1981-02-01  St. John's  Newfoundland and Labrador    Land only
# 4      1981-03-01  St. John's  Newfoundland and Labrador   House only
# ...           ...         ...                        ...          ...
# 15219  2020-05-01     Kelowna           British Columbia    Land only
# 15220  2020-06-01     Kelowna           British Columbia   House only
# 15221  2020-06-01     Kelowna           British Columbia    Land only
# 15222  2020-07-01     Kelowna           British Columbia   House only
# 15223  2020-07-01     Kelowna           British Columbia    Land only
#
#        PRICE_INDEX                                   city_size_type city_type  \
# 0               37  Large urban population centre (100,000 or more)      Core
# 1               31  Large urban population centre (100,000 or more)      Core
# 2               37  Large urban population centre (100,000 or more)      Core
# 3               31  Large urban population centre (100,000 or more)      Core
# 4               37  Large urban population centre (100,000 or more)      Core
# ...            ...                                              ...       ...
# 15219          101  Large urban population centre (100,000 or more)      Core
# 15220          105  Large urban population centre (100,000 or more)      Core
# 15221          101  Large urban population centre (100,000 or more)      Core
# 15222          106  Large urban population centre (100,000 or more)      Core
# 15223          101  Large urban population centre (100,000 or more)      Core
#
#        pop_2016  city_size  pop_density
# 0      178427.0     166.00       1074.9
# 1      178427.0     166.00       1074.9
# 2      178427.0     166.00       1074.9
# 3      178427.0     166.00       1074.9
# 4      178427.0     166.00       1074.9
# ...         ...        ...          ...
# 15219  151957.0     136.44       1113.8
# 15220  151957.0     136.44       1113.8
# 15221  151957.0     136.44       1113.8
# 15222  151957.0     136.44       1113.8
# 15223  151957.0     136.44       1113.8
#
# [15224 rows x 10 columns]

# %%
# Utilizing Combined_df_1 dataset instead of combined_df_2 (aka neglecting number of units available/sold/unsold)
# Find duplicated entries 
print(f"Duplication entries: {combined_df_1.duplicated().sum()}")
combined_df_1 = combined_df_1.drop_duplicates()
combined_df_1
# Out:
# Duplication entries: 0
#          REF_DATE        City                   Province Housing_Type  \
# 0      1981-01-01  St. John's  Newfoundland and Labrador   House only
# 1      1981-01-01  St. John's  Newfoundland and Labrador    Land only
# 2      1981-02-01  St. John's  Newfoundland and Labrador   House only
# 3      1981-02-01  St. John's  Newfoundland and Labrador    Land only
# 4      1981-03-01  St. John's  Newfoundland and Labrador   House only
# ...           ...         ...                        ...          ...
# 15219  2020-05-01     Kelowna           British Columbia    Land only
# 15220  2020-06-01     Kelowna           British Columbia   House only
# 15221  2020-06-01     Kelowna           British Columbia    Land only
# 15222  2020-07-01     Kelowna           British Columbia   House only
# 15223  2020-07-01     Kelowna           British Columbia    Land only
#
#        PRICE_INDEX                                   city_size_type city_type  \
# 0               37  Large urban population centre (100,000 or more)      Core
# 1               31  Large urban population centre (100,000 or more)      Core
# 2               37  Large urban population centre (100,000 or more)      Core
# 3               31  Large urban population centre (100,000 or more)      Core
# 4               37  Large urban population centre (100,000 or more)      Core
# ...            ...                                              ...       ...
# 15219          101  Large urban population centre (100,000 or more)      Core
# 15220          105  Large urban population centre (100,000 or more)      Core
# 15221          101  Large urban population centre (100,000 or more)      Core
# 15222          106  Large urban population centre (100,000 or more)      Core
# 15223          101  Large urban population centre (100,000 or more)      Core
#
#        pop_2016  city_size  pop_density
# 0      178427.0     166.00       1074.9
# 1      178427.0     166.00       1074.9
# 2      178427.0     166.00       1074.9
# 3      178427.0     166.00       1074.9
# 4      178427.0     166.00       1074.9
# ...         ...        ...          ...
# 15219  151957.0     136.44       1113.8
# 15220  151957.0     136.44       1113.8
# 15221  151957.0     136.44       1113.8
# 15222  151957.0     136.44       1113.8
# 15223  151957.0     136.44       1113.8
#
# [15224 rows x 10 columns]

# %%
city_counts = combined_df_1.City.value_counts()
city_counts
# Out:
# Vancouver         950
# Québec            950
# Toronto           950
# Saskatoon         950
# Calgary           950
# Winnipeg          950
# Regina            950
# Montréal          950
# Windsor           950
# St. John's        950
# London            950
# Victoria          950
# Hamilton          950
# Edmonton          950
# Halifax           870
# Charlottetown     614
# Trois-Rivières     88
# Guelph             88
# Sherbrooke         88
# Kelowna            88
# Oshawa             88
# Name: City, dtype: int64

# %%
province_counts = combined_df_1.Province.value_counts()
province_counts
# Out:
# Ontario                      3976
# Quebec                       2076
# British Columbia             1988
# Alberta                      1900
# Saskatchewan                 1900
# Newfoundland and Labrador     950
# Manitoba                      950
# Nova Scotia                   870
# Prince Edward Island          614
# Name: Province, dtype: int64

# %%
house_type_counts = combined_df_1.Housing_Type.value_counts()
house_type_counts
# Out:
# Land only     7612
# House only    7612
# Name: Housing_Type, dtype: int64

# %%
city_size_type_count = combined_df_1.city_size_type.value_counts()
city_size_type_count
# Out:
# Large urban population centre (100,000 or more)    14610
# Medium population centre (30,000 to 99,999)          614
# Name: city_size_type, dtype: int64

# %%
city_type = combined_df_1.city_type.value_counts()
city_type
# Out:
# Core    15224
# Name: city_type, dtype: int64

# %%
combined_df_1 = combined_df_1.drop(columns = ["city_type"])
combined_df_1
# Out:
#          REF_DATE        City                   Province Housing_Type  \
# 0      1981-01-01  St. John's  Newfoundland and Labrador   House only
# 1      1981-01-01  St. John's  Newfoundland and Labrador    Land only
# 2      1981-02-01  St. John's  Newfoundland and Labrador   House only
# 3      1981-02-01  St. John's  Newfoundland and Labrador    Land only
# 4      1981-03-01  St. John's  Newfoundland and Labrador   House only
# ...           ...         ...                        ...          ...
# 15219  2020-05-01     Kelowna           British Columbia    Land only
# 15220  2020-06-01     Kelowna           British Columbia   House only
# 15221  2020-06-01     Kelowna           British Columbia    Land only
# 15222  2020-07-01     Kelowna           British Columbia   House only
# 15223  2020-07-01     Kelowna           British Columbia    Land only
#
#        PRICE_INDEX                                   city_size_type  pop_2016  \
# 0               37  Large urban population centre (100,000 or more)  178427.0
# 1               31  Large urban population centre (100,000 or more)  178427.0
# 2               37  Large urban population centre (100,000 or more)  178427.0
# 3               31  Large urban population centre (100,000 or more)  178427.0
# 4               37  Large urban population centre (100,000 or more)  178427.0
# ...            ...                                              ...       ...
# 15219          101  Large urban population centre (100,000 or more)  151957.0
# 15220          105  Large urban population centre (100,000 or more)  151957.0
# 15221          101  Large urban population centre (100,000 or more)  151957.0
# 15222          106  Large urban population centre (100,000 or more)  151957.0
# 15223          101  Large urban population centre (100,000 or more)  151957.0
#
#        city_size  pop_density
# 0         166.00       1074.9
# 1         166.00       1074.9
# 2         166.00       1074.9
# 3         166.00       1074.9
# 4         166.00       1074.9
# ...          ...          ...
# 15219     136.44       1113.8
# 15220     136.44       1113.8
# 15221     136.44       1113.8
# 15222     136.44       1113.8
# 15223     136.44       1113.8
#
# [15224 rows x 9 columns]

# %%
combined_df_1["REF_DATE"] = combined_df_1["REF_DATE"].astype("datetime64")

# %%
# Isolate for specific province
#province = "Ontario"
#combined_df_4 = combined_df_1[(combined_df_1["Province"] == province) & (combined_df_1["Housing_Type"] == "House only")]
#combined_df_4

combined_df_4 = combined_df_1[combined_df_1["Housing_Type"] == "Land only"]
combined_df_4
# Out:
#         REF_DATE        City                   Province Housing_Type  \
# 1     1981-01-01  St. John's  Newfoundland and Labrador    Land only
# 3     1981-02-01  St. John's  Newfoundland and Labrador    Land only
# 5     1981-03-01  St. John's  Newfoundland and Labrador    Land only
# 7     1981-04-01  St. John's  Newfoundland and Labrador    Land only
# 9     1981-05-01  St. John's  Newfoundland and Labrador    Land only
# ...          ...         ...                        ...          ...
# 15215 2020-03-01     Kelowna           British Columbia    Land only
# 15217 2020-04-01     Kelowna           British Columbia    Land only
# 15219 2020-05-01     Kelowna           British Columbia    Land only
# 15221 2020-06-01     Kelowna           British Columbia    Land only
# 15223 2020-07-01     Kelowna           British Columbia    Land only
#
#        PRICE_INDEX                                   city_size_type  pop_2016  \
# 1               31  Large urban population centre (100,000 or more)  178427.0
# 3               31  Large urban population centre (100,000 or more)  178427.0
# 5               31  Large urban population centre (100,000 or more)  178427.0
# 7               31  Large urban population centre (100,000 or more)  178427.0
# 9               31  Large urban population centre (100,000 or more)  178427.0
# ...            ...                                              ...       ...
# 15215          101  Large urban population centre (100,000 or more)  151957.0
# 15217          101  Large urban population centre (100,000 or more)  151957.0
# 15219          101  Large urban population centre (100,000 or more)  151957.0
# 15221          101  Large urban population centre (100,000 or more)  151957.0
# 15223          101  Large urban population centre (100,000 or more)  151957.0
#
#        city_size  pop_density
# 1         166.00       1074.9
# 3         166.00       1074.9
# 5         166.00       1074.9
# 7         166.00       1074.9
# 9         166.00       1074.9
# ...          ...          ...
# 15215     136.44       1113.8
# 15217     136.44       1113.8
# 15219     136.44       1113.8
# 15221     136.44       1113.8
# 15223     136.44       1113.8
#
# [7612 rows x 9 columns]

# %%
# Refine by start date
start_date = datetime(2015,1,1)
combined_df_4 = combined_df_4[combined_df_4["REF_DATE"] > start_date]
combined_df_4
# Out:
#         REF_DATE        City                   Province Housing_Type  \
# 819   2015-02-01  St. John's  Newfoundland and Labrador    Land only
# 821   2015-03-01  St. John's  Newfoundland and Labrador    Land only
# 823   2015-04-01  St. John's  Newfoundland and Labrador    Land only
# 825   2015-05-01  St. John's  Newfoundland and Labrador    Land only
# 827   2015-06-01  St. John's  Newfoundland and Labrador    Land only
# ...          ...         ...                        ...          ...
# 15215 2020-03-01     Kelowna           British Columbia    Land only
# 15217 2020-04-01     Kelowna           British Columbia    Land only
# 15219 2020-05-01     Kelowna           British Columbia    Land only
# 15221 2020-06-01     Kelowna           British Columbia    Land only
# 15223 2020-07-01     Kelowna           British Columbia    Land only
#
#        PRICE_INDEX                                   city_size_type  pop_2016  \
# 819             98  Large urban population centre (100,000 or more)  178427.0
# 821             98  Large urban population centre (100,000 or more)  178427.0
# 823             98  Large urban population centre (100,000 or more)  178427.0
# 825             99  Large urban population centre (100,000 or more)  178427.0
# 827             99  Large urban population centre (100,000 or more)  178427.0
# ...            ...                                              ...       ...
# 15215          101  Large urban population centre (100,000 or more)  151957.0
# 15217          101  Large urban population centre (100,000 or more)  151957.0
# 15219          101  Large urban population centre (100,000 or more)  151957.0
# 15221          101  Large urban population centre (100,000 or more)  151957.0
# 15223          101  Large urban population centre (100,000 or more)  151957.0
#
#        city_size  pop_density
# 819       166.00       1074.9
# 821       166.00       1074.9
# 823       166.00       1074.9
# 825       166.00       1074.9
# 827       166.00       1074.9
# ...          ...          ...
# 15215     136.44       1113.8
# 15217     136.44       1113.8
# 15219     136.44       1113.8
# 15221     136.44       1113.8
# 15223     136.44       1113.8
#
# [1276 rows x 9 columns]

# %%
combined_df_4["Year"] = pd.DatetimeIndex(combined_df_4['REF_DATE']).year
# Out:
# C:\Users\JD\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
x_data = combined_df_4.groupby(["City", "Year", "pop_density"])["PRICE_INDEX"].mean()
x_df = pd.DataFrame(data = x_data)
new_df = pd.DataFrame(x_df.to_records())
new_df.drop(columns = ["City"], inplace = True)
new_df
# Out:
#      Year  pop_density  PRICE_INDEX
# 0    2015       2111.8    97.636364
# 1    2016       2111.8    98.750000
# 2    2017       2111.8    99.916667
# 3    2018       2111.8   100.000000
# 4    2019       2111.8    99.666667
# ..    ...          ...          ...
# 116  2016       2069.6    99.166667
# 117  2017       2069.6   100.000000
# 118  2018       2069.6   100.750000
# 119  2019       2069.6   101.000000
# 120  2020       2069.6   102.000000
#
# [121 rows x 3 columns]

# %%
new_df.dtypes
# Out:
# Year             int32
# pop_density    float64
# PRICE_INDEX    float64
# dtype: object

# %%
new_df_1 = new_df[new_df["Year"] < 2020]
new_df_1
# Out:
#      Year  pop_density  PRICE_INDEX
# 0    2015       2111.8    97.636364
# 1    2016       2111.8    98.750000
# 2    2017       2111.8    99.916667
# 3    2018       2111.8   100.000000
# 4    2019       2111.8    99.666667
# ..    ...          ...          ...
# 115  2015       2069.6    98.636364
# 116  2016       2069.6    99.166667
# 117  2017       2069.6   100.000000
# 118  2018       2069.6   100.750000
# 119  2019       2069.6   101.000000
#
# [100 rows x 3 columns]

# %%
X = new_df_1[['pop_density','Year']] 
Y = new_df_1['PRICE_INDEX']

# %%
# with statsmodels
X = sm.add_constant(X) # adding a constant
 
model = sm.OLS(Y, X).fit()
predictions = model.predict(X) 
 
print_model = model.summary()
print(print_model)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            PRICE_INDEX   R-squared:                       0.386
# Model:                            OLS   Adj. R-squared:                  0.373
# Method:                 Least Squares   F-statistic:                     30.49
# Date:                Wed, 30 Sep 2020   Prob (F-statistic):           5.31e-11
# Time:                        14:40:43   Log-Likelihood:                -199.14
# No. Observations:                 100   AIC:                             404.3
# Df Residuals:                      97   BIC:                             412.1
# Df Model:                           2
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const       -1825.2731    264.234     -6.908      0.000   -2349.705   -1300.841
# pop_density     0.0011      0.000      3.066      0.003       0.000       0.002
# Year            0.9538      0.131      7.281      0.000       0.694       1.214
# ==============================================================================
# Omnibus:                        8.240   Durbin-Watson:                   0.840
# Prob(Omnibus):                  0.016   Jarque-Bera (JB):                8.608
# Skew:                           0.521   Prob(JB):                       0.0135
# Kurtosis:                       3.991   Cond. No.                     4.03e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.03e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
new_df_2 = new_df[new_df["Year"] == 2020]
X2 = new_df_2[['pop_density','Year']] 
X2.insert(0, 'const', 1, allow_duplicates=True)

# %%
predictions2 = model.predict(X2) 
predictions2
# Out:
# 5      103.540175
# 11     102.268276
# 17     103.269511
# 22     103.196855
# 28     102.734942
# 34     103.392963
# 39     102.486243
# 45     103.051755
# 51     104.182355
# 56     103.420314
# 62     103.051227
# 68     103.508177
# 74     103.373215
# 79     102.839912
# 85     102.445163
# 91     104.507934
# 96     102.979838
# 102    104.038945
# 108    102.952170
# 114    103.030423
# 120    103.495610
# dtype: float64

# %%
new_df_c = pd.DataFrame(x_df.to_records())
new_df_c = new_df_c[new_df_c["Year"] == 2020]
new_df_c
# Out:
#                City  Year  pop_density  PRICE_INDEX
# 5           Calgary  2020       2111.8    99.428571
# 11    Charlottetown  2020        907.4   100.000000
# 17         Edmonton  2020       1855.5   100.000000
# 22           Guelph  2020       1786.7   105.428571
# 28          Halifax  2020       1349.3   100.714286
# 34         Hamilton  2020       1972.4   100.714286
# 39          Kelowna  2020       1113.8   101.000000
# 45           London  2020       1649.3   102.857143
# 51         Montréal  2020       2719.9   105.714286
# 56           Oshawa  2020       1998.3   105.285714
# 62           Québec  2020       1648.8   101.000000
# 68           Regina  2020       2081.5    99.571429
# 74        Saskatoon  2020       1953.7   100.000000
# 79       Sherbrooke  2020       1448.7   103.000000
# 85       St. John's  2020       1074.9    99.000000
# 91          Toronto  2020       3028.2   108.142857
# 96   Trois-Rivières  2020       1581.2   101.000000
# 102       Vancouver  2020       2584.1   107.285714
# 108        Victoria  2020       1555.0   102.142857
# 114         Windsor  2020       1629.1   107.857143
# 120        Winnipeg  2020       2069.6   102.000000

# %%
new_df_c['PRICE_INDEX_P'] = predictions2

# %%
new_df_c.reset_index(inplace = True) 
new_df_c
# Out:
#     index            City  Year  pop_density  PRICE_INDEX  PRICE_INDEX_P
# 0       5         Calgary  2020       2111.8    99.428571     103.540175
# 1      11   Charlottetown  2020        907.4   100.000000     102.268276
# 2      17        Edmonton  2020       1855.5   100.000000     103.269511
# 3      22          Guelph  2020       1786.7   105.428571     103.196855
# 4      28         Halifax  2020       1349.3   100.714286     102.734942
# 5      34        Hamilton  2020       1972.4   100.714286     103.392963
# 6      39         Kelowna  2020       1113.8   101.000000     102.486243
# 7      45          London  2020       1649.3   102.857143     103.051755
# 8      51        Montréal  2020       2719.9   105.714286     104.182355
# 9      56          Oshawa  2020       1998.3   105.285714     103.420314
# 10     62          Québec  2020       1648.8   101.000000     103.051227
# 11     68          Regina  2020       2081.5    99.571429     103.508177
# 12     74       Saskatoon  2020       1953.7   100.000000     103.373215
# 13     79      Sherbrooke  2020       1448.7   103.000000     102.839912
# 14     85      St. John's  2020       1074.9    99.000000     102.445163
# 15     91         Toronto  2020       3028.2   108.142857     104.507934
# 16     96  Trois-Rivières  2020       1581.2   101.000000     102.979838
# 17    102       Vancouver  2020       2584.1   107.285714     104.038945
# 18    108        Victoria  2020       1555.0   102.142857     102.952170
# 19    114         Windsor  2020       1629.1   107.857143     103.030423
# 20    120        Winnipeg  2020       2069.6   102.000000     103.495610

# %%
combined_df_4['PRICE_INDEX_P'] = combined_df_4['PRICE_INDEX'].astype(float)
combined_df_4.head()
# Out:
# C:\Users\JD\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#       REF_DATE        City                   Province Housing_Type  \
# 819 2015-02-01  St. John's  Newfoundland and Labrador    Land only
# 821 2015-03-01  St. John's  Newfoundland and Labrador    Land only
# 823 2015-04-01  St. John's  Newfoundland and Labrador    Land only
# 825 2015-05-01  St. John's  Newfoundland and Labrador    Land only
# 827 2015-06-01  St. John's  Newfoundland and Labrador    Land only
#
#      PRICE_INDEX                                   city_size_type  pop_2016  \
# 819           98  Large urban population centre (100,000 or more)  178427.0
# 821           98  Large urban population centre (100,000 or more)  178427.0
# 823           98  Large urban population centre (100,000 or more)  178427.0
# 825           99  Large urban population centre (100,000 or more)  178427.0
# 827           99  Large urban population centre (100,000 or more)  178427.0
#
#      city_size  pop_density  Year  PRICE_INDEX_P
# 819      166.0       1074.9  2015           98.0
# 821      166.0       1074.9  2015           98.0
# 823      166.0       1074.9  2015           98.0
# 825      166.0       1074.9  2015           99.0
# 827      166.0       1074.9  2015           99.0

# %%
for i, row in combined_df_4.iterrows():
    for j, row2 in new_df_c.iterrows():
        ifor_val = new_df_c.at[j,'PRICE_INDEX_P']
        if (combined_df_4.at[i,'City'] == new_df_c.at[j,'City']) and (combined_df_4.at[i,'Year'] == new_df_c.at[j,'Year']) :
            combined_df_4.at[i,'PRICE_INDEX_P'] = ifor_val

# %%
combined_df_4.to_csv(r'C:\Users\JD\Desktop\Analysis_Projects\Final_project\Covid_and_Real_Estate_Canada\Resources\export.df_supervised_rev1_land.csv', index = False, header=True)

# %%
combined_df_4_homes = pd.read_csv("../Resources/export.df_supervised_rev1_homes.csv")

# %%
combined_df_4_homes["REF_DATE"] = combined_df_4_homes["REF_DATE"].astype("datetime64")

# %%
df_for_dash = pd.concat([combined_df_4_homes,combined_df_4])

# %%
df_for_dash
# Out:
#         REF_DATE        City                   Province Housing_Type  \
# 0     2015-02-01  St. John's  Newfoundland and Labrador   House only
# 1     2015-03-01  St. John's  Newfoundland and Labrador   House only
# 2     2015-04-01  St. John's  Newfoundland and Labrador   House only
# 3     2015-05-01  St. John's  Newfoundland and Labrador   House only
# 4     2015-06-01  St. John's  Newfoundland and Labrador   House only
# ...          ...         ...                        ...          ...
# 15215 2020-03-01     Kelowna           British Columbia    Land only
# 15217 2020-04-01     Kelowna           British Columbia    Land only
# 15219 2020-05-01     Kelowna           British Columbia    Land only
# 15221 2020-06-01     Kelowna           British Columbia    Land only
# 15223 2020-07-01     Kelowna           British Columbia    Land only
#
#        PRICE_INDEX                                   city_size_type  pop_2016  \
# 0              100  Large urban population centre (100,000 or more)  178427.0
# 1              100  Large urban population centre (100,000 or more)  178427.0
# 2              100  Large urban population centre (100,000 or more)  178427.0
# 3               99  Large urban population centre (100,000 or more)  178427.0
# 4               99  Large urban population centre (100,000 or more)  178427.0
# ...            ...                                              ...       ...
# 15215          101  Large urban population centre (100,000 or more)  151957.0
# 15217          101  Large urban population centre (100,000 or more)  151957.0
# 15219          101  Large urban population centre (100,000 or more)  151957.0
# 15221          101  Large urban population centre (100,000 or more)  151957.0
# 15223          101  Large urban population centre (100,000 or more)  151957.0
#
#        city_size  pop_density  Year  PRICE_INDEX_P
# 0         166.00       1074.9  2015     100.000000
# 1         166.00       1074.9  2015     100.000000
# 2         166.00       1074.9  2015     100.000000
# 3         166.00       1074.9  2015      99.000000
# 4         166.00       1074.9  2015      99.000000
# ...          ...          ...   ...            ...
# 15215     136.44       1113.8  2020     102.486243
# 15217     136.44       1113.8  2020     102.486243
# 15219     136.44       1113.8  2020     102.486243
# 15221     136.44       1113.8  2020     102.486243
# 15223     136.44       1113.8  2020     102.486243
#
# [2552 rows x 11 columns]

# %%
df_for_dash.to_csv(r'C:\Users\JD\Desktop\Analysis_Projects\Final_project\Covid_and_Real_Estate_Canada\Resources\export.df_supervised_rev1_land_homes.csv', index = False, header=True)
